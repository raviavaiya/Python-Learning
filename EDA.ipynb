# %% [markdown]
# EDA
# -

# %%
import pandas as pd

# %%
df=pd.read_csv("Marvel Movies.csv")

# %%
df.columns
# Out:
# Index(['movie', 'category', 'year', 'worldwide gross ($m)',
#        '% budget recovered', 'critics % score', 'audience % score',
#        'audience vs critics % deviance', 'budget', 'domestic gross ($m)',
#        'international gross ($m)', 'opening weekend ($m)',
#        'second weekend ($m)', '1st vs 2nd weekend drop off',
#        '% gross from opening weekend', '% gross from domestic',
#        '% gross from international', '% budget opening weekend'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   movie                           37 non-null     object
#  1   category                        35 non-null     object
#  2   year                            36 non-null     float64
#  3   worldwide gross ($m)            37 non-null     int64
#  4   % budget recovered              37 non-null     object
#  5   critics % score                 36 non-null     object
#  6   audience % score                37 non-null     object
#  7   audience vs critics % deviance  37 non-null     object
#  8   budget                          37 non-null     float64
#  9   domestic gross ($m)             37 non-null     int64
#  10  international gross ($m)        37 non-null     int64
#  11  opening weekend ($m)            37 non-null     float64
# ...

# %%
df.describe()
# Out:
#               year  worldwide gross ($m)      budget  domestic gross ($m)  \
# count    36.000000             37.000000   37.000000            37.000000
# mean   2016.972222            886.945946  192.608108           355.675676
# std       4.378428            521.781294   67.939836           179.834655
# min    2008.000000            265.000000   58.000000           134.000000
# 25%    2014.000000            518.000000  150.000000           215.000000
# 50%    2017.000000            770.000000  180.000000           333.000000
# 75%    2021.000000           1129.000000  225.000000           408.000000
# max    2023.000000           2797.000000  400.000000           858.000000
#
#        international gross ($m)  opening weekend ($m)  second weekend ($m)  \
# count                 37.000000             37.000000            37.000000
# mean                 530.837838            130.837838            54.208108
# std                  358.709687             66.560075            28.612909
# ...

# %%
df.isnull()
# Out:
#     movie  category   year  worldwide gross ($m)  % budget recovered  \
# 0   False     False  False                 False               False
# 1   False     False  False                 False               False
# 2   False     False   True                 False               False
# 3   False     False  False                 False               False
# 4   False     False  False                 False               False
# 5   False     False  False                 False               False
# 6   False     False  False                 False               False
# 7   False      True  False                 False               False
# 8   False     False  False                 False               False
# 9   False     False  False                 False               False
# 10  False     False  False                 False               False
# 11  False     False  False                 False               False
# 12  False     False  False                 False               False
# ...

# %%
df.isna()
# Out:
#     movie  category   year  worldwide gross ($m)  % budget recovered  \
# 0   False     False  False                 False               False
# 1   False     False  False                 False               False
# 2   False     False   True                 False               False
# 3   False     False  False                 False               False
# 4   False     False  False                 False               False
# 5   False     False  False                 False               False
# 6   False     False  False                 False               False
# 7   False      True  False                 False               False
# 8   False     False  False                 False               False
# 9   False     False  False                 False               False
# 10  False     False  False                 False               False
# 11  False     False  False                 False               False
# 12  False     False  False                 False               False
# ...

# %%
df['year'].isna()
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# Name: year, dtype: bool

# %%
flag=df[df['year'].isna()].index

# %%
flag
# Out:
# Index([2], dtype='int64')

# %%
df.drop(flag,axis=0)
# Out:
#                                   movie         category    year  \
# 0                             Ant-Man            Ant-Man  2015.0
# 1                             Ant-Man            Ant-Man  2015.0
# 3               Avengers: Age of Ultron         Avengers  2015.0
# 4                    Avengers: End Game         Avengers  2019.0
# 5                Avengers: Infinity War         Avengers  2018.0
# 6                         Black Panther    Black Panther  2018.0
# 7                       Black Panther 2              NaN  2022.0
# 8                           Black Widow           Unique  2021.0
# 9                       Captain America  Captain America  2011.0
# 10           Captain America: Civil War  Captain America  2016.0
# 11      Captain America: Winter Soldier  Captain America  2014.0
# 12                       Captain Marvel           Unique  2019.0
# 13                           Dr Strange              NaN  2016.0
# ...

# %% [markdown]
# Removing Entire  Rows = 0 or Columns = 1

# %%
df.drop('year',axis=1)
# Out:
#                                   movie         category  \
# 0                             Ant-Man            Ant-Man
# 1                             Ant-Man            Ant-Man
# 2                    Ant-Man & The Wasp          Ant-Man
# 3               Avengers: Age of Ultron         Avengers
# 4                    Avengers: End Game         Avengers
# 5                Avengers: Infinity War         Avengers
# 6                         Black Panther    Black Panther
# 7                       Black Panther 2              NaN
# 8                           Black Widow           Unique
# 9                       Captain America  Captain America
# 10           Captain America: Civil War  Captain America
# 11      Captain America: Winter Soldier  Captain America
# 12                       Captain Marvel           Unique
# 13                           Dr Strange              NaN
# 14    Dr Strange: Multiverse of Madness       Dr Strange
# ...

# %%
df.dropna(axis=1)
# Out:
#                                   movie  worldwide gross ($m)  \
# 0                             Ant-Man                     518
# 1                             Ant-Man                     518
# 2                    Ant-Man & The Wasp                   623
# 3               Avengers: Age of Ultron                  1395
# 4                    Avengers: End Game                  2797
# 5                Avengers: Infinity War                  2048
# 6                         Black Panther                  1336
# 7                       Black Panther 2                   855
# 8                           Black Widow                   379
# 9                       Captain America                   370
# 10           Captain America: Civil War                  1151
# 11      Captain America: Winter Soldier                   714
# 12                       Captain Marvel                  1129
# 13                           Dr Strange                   676
# ...

# %%
df.fillna('NA')
# Out:
#                                   movie         category    year  \
# 0                             Ant-Man            Ant-Man  2015.0
# 1                             Ant-Man            Ant-Man  2015.0
# 2                    Ant-Man & The Wasp          Ant-Man      NA
# 3               Avengers: Age of Ultron         Avengers  2015.0
# 4                    Avengers: End Game         Avengers  2019.0
# 5                Avengers: Infinity War         Avengers  2018.0
# 6                         Black Panther    Black Panther  2018.0
# 7                       Black Panther 2               NA  2022.0
# 8                           Black Widow           Unique  2021.0
# 9                       Captain America  Captain America  2011.0
# 10           Captain America: Civil War  Captain America  2016.0
# 11      Captain America: Winter Soldier  Captain America  2014.0
# 12                       Captain Marvel           Unique  2019.0
# ...

# %% [markdown]
# FFILL & BFILL

# %%
df['year'].ffill()
# Out:
# 0     2015.0
# 1     2015.0
# 2     2015.0
# 3     2015.0
# 4     2019.0
# 5     2018.0
# 6     2018.0
# 7     2022.0
# 8     2021.0
# 9     2011.0
# 10    2016.0
# 11    2014.0
# 12    2019.0
# 13    2016.0
# 14    2022.0
# 15    2021.0
# 16    2014.0
# 17    2017.0
# 18    2008.0
# 19    2008.0
# 20    2010.0
# 21    2013.0
# 22    2021.0
# 23    2019.0
# 24    2017.0
# 25    2021.0
# 26    2012.0
# 27    2013.0
# 28    2022.0
# 29    2017.0
# 30    2011.0
# 31    2023.0
# 32    2023.0
# 33    2023.0
# 34    2023.0
# 35    2016.0
# 36    2018.0
# Name: year, dtype: float64

# %%
df['year'].bfill()
# Out:
# 0     2015.0
# 1     2015.0
# 2     2015.0
# 3     2015.0
# 4     2019.0
# 5     2018.0
# 6     2018.0
# 7     2022.0
# 8     2021.0
# 9     2011.0
# 10    2016.0
# 11    2014.0
# 12    2019.0
# 13    2016.0
# 14    2022.0
# 15    2021.0
# 16    2014.0
# 17    2017.0
# 18    2008.0
# 19    2008.0
# 20    2010.0
# 21    2013.0
# 22    2021.0
# 23    2019.0
# 24    2017.0
# 25    2021.0
# 26    2012.0
# 27    2013.0
# 28    2022.0
# 29    2017.0
# 30    2011.0
# 31    2023.0
# 32    2023.0
# 33    2023.0
# 34    2023.0
# 35    2016.0
# 36    2018.0
# Name: year, dtype: float64
